# %% [markdown]
# # BASE MODEL
# # 94 - 812: Applications of NL(X) and LLMs
# ## Team Programming Assignment
#
# ### March 1st 2024
#
# Muhammad Asghar, Davis Craig, Hiba Hassan, Grace Kim, Talia Qaiser, Abdul Rehman, Alex Yang

# %% [markdown]
# ## 0. Installing Necessary Libraries and Authenticating Hugging Face Account

# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in /jet/home/arehman1/.local/lib/python3.10/site-packages (4.38.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /jet/home/arehman1/.local/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /jet/home/arehman1/.local/lib/python3.10/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /jet/home/arehman1/.local/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /jet/home/arehman1/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.0a0+81ea7a4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /jet/home/arehman1/.local/lib/python3.10/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import torch

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# if you need here is my login token:
# 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

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## 1. Prompt Engineering Models

# %% [markdown]
# In this section we will assess the use of 5 prompt engineering models/techniques with our base model

# %% [markdown]
# ### Model 1: Zero Shot Learning

# %% [markdown]
# "The prompt has no examples, and the model tries to generate the answer without any examples."   [Ref. 1 - Rao, 2024]

# %%
# #Zero-Shot Learning
# #base model

# zero_shot = """
# Task Description: Below is a question followed by an answer. Write a response that gives a holistic AI policy for a problem when prompted. It should have some or all of the following components if relevant to the problem:

# Ethical Principles
# Transparency and Explainability
# Fairness and Bias Mitigation
# Accountability and Responsibility
# Privacy Protection
# Security Measures
# User Consent and Control
# Data Governance
# Collaboration and Stakeholder Engagement
# Compliance with Regulations
# Robust Testing and Validation
# Human-in-the-Loop
# Continuous Improvement
# Emergency Protocols

# Prompt: What are the key steps in development of an AI policy framework?"""

zero_shot = """What are the key steps in development of an AI policy framework?"""

# %%
# batch = tokenizer(zero_shot, return_tensors='pt')

# with torch.cuda.amp.autocast():
#   output_tokens = model.generate(**batch, max_new_tokens=10)

# print('\n\n', tokenizer.decode(output_tokens[0], skip_special_tokens=True))

# %%
# # If using a GPU, ensure the model is moved to GPU
# model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Prompts without PE

# %%
def get_response(question):
  batch = tokenizer(question, return_tensors='pt')

  with torch.cuda.amp.autocast():
    output_tokens = model.generate(**batch, max_new_tokens=500)

  response = tokenizer.decode(output_tokens[0], skip_special_tokens=True)
  return response

# %%
q1 = """What are the key steps in the development of an AI policy framework?"""
q2 = """Give me an AI development policy for a governmental organization."""
q3 = """What kind of consumer data protection policies should an online retail organization consider?"""
q4 = """How does a financial institution ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive financial information and transactions?"""
q5 = """Explain the importance of compliance and regulation in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response."""
q6 = """You should give a clear policy for the tech industry.""" # using tech industry as an example

# %% [markdown]
# Question 1

# %%
print(q1)
# Out:
# What are the key steps in the development of an AI policy framework?

# %%
response_q1 = get_response(q1)
print(response_q1)
# Out:
# What are the key steps in the development of an AI policy framework?
# A: The first step is to identify the problem or opportunity that the AI policy is intended to address. This may involve conducting a needs assessment to understand the current state of AI in the country and the potential benefits and risks associated with its use.
# The next step is to develop a clear and concise statement of the policy goals, objectives, and principles that will guide the development and implementation of the AI policy. This may involve consulting with stakeholders, such as industry, academia, and civil society, to ensure that the policy takes into account the diverse perspectives and needs of different groups.
# Once the policy goals and objectives have been identified, the next step is to develop a set of actions or initiatives that will be taken to achieve these goals. This may involve identifying specific targets or metrics for measuring progress, as well as setting timelines and deadlines for achieving these goals.
# The final step is to develop a roadmap for the implementation of the AI policy, which may involve creating a plan for allocating resources and managing stakeholder engagement throughout the implementation process.
# What are the key considerations in developing an AI policy framework?
# A: The key considerations in developing an AI policy framework include:
# Identifying the problem or opportunity that the policy is intended to address
# Developing clear and concise policy goals, objectives, and principles
# Developing a set of actions or initiatives that will be taken to achieve these goals
# Identifying specific targets or metrics for measuring progress
# Setting timelines and deadlines for achieving these goals
# Creating a plan for allocating resources and managing stakeholder engagement throughout the implementation process
# What are the key benefits of developing an AI policy framework?
# A: The key benefits of developing an AI policy framework include:
# Providing a clear and concise statement of the policy goals and objectives that will guide the development and implementation of the AI policy
# Enabling the effective and efficient implementation of the policy, by identifying specific targets or metrics for measuring progress and setting timelines and deadlines for achieving these goals
# Promoting transparency and accountability in the development and implementation of the policy, by involving stakeholders and creating a plan for allocating resources and managing stakeholder engagement throughout the implementation process
# Providing

# %% [markdown]
# Question 2

# %%
print(q2)
# Out:
# Give me an AI development policy for a governmental organization.

# %%
response_q2 = get_response(q2)
print(response_q2)
# Out:
# Give me an AI development policy for a governmental organization.
# I’m working on a paper about the future of AI for a governmental organization. I’d like to know what you think about the following statement:
# “The government should create a policy to develop AI in a way that is beneficial to society. This policy should include the following:
# – A clear definition of what AI is and how it is being used
# – A plan for how AI will be used in the future
# – A plan for how AI will be regulated
# – A plan for how AI will be funded
# – A plan for how AI will be monitored and evaluated
# – A plan for how AI will be used in the workplace
# – A plan for how AI will be used in the home
# – A plan for how AI will be used in the classroom
# – A plan for how AI will be used in the military
# – A plan for how AI will be used in the healthcare industry
# – A plan for how AI will be used in the retail industry
# – A plan for how AI will be used in the transportation industry
# – A plan for how AI will be used in the agriculture industry
# – A plan for how AI will be used in the energy industry
# – A plan for how AI will be used in the banking industry
# – A plan for how AI will be used in the insurance industry
# – A plan for how AI will be used in the media industry
# – A plan for how AI will be used in the education industry
# – A plan for how AI will be used in the entertainment industry
# – A plan for how AI will be used in the manufacturing industry
# – A plan for how AI will be used in the construction industry
# – A plan for how AI will be used in the mining industry
# – A plan for how AI will be used in the automotive industry
# – A plan for how AI will be used in the aerospace industry
# – A plan for how AI will be used in the defense industry
# – A plan for how AI will be used in the healthcare industry
# – A plan for how AI will be used in the transportation industry
# – A plan for how AI will be used in the agriculture industry
# – A plan for how AI will be

# %% [markdown]
# Question 3

# %%
print(q3)
# Out:
# What kind of consumer data protection policies should an online retail organization consider?

# %%
response_q3 = get_response(q3)
print(response_q3)
# Out:
# What kind of consumer data protection policies should an online retail organization consider?
# There are many consumer data protection policies that an online retail organization should consider. These policies include:
# Data breach policies.
# Data collection policies.
# Data access policies.
# Data sharing policies.
# Data disposal policies.
# Data privacy policies.
# Data security policies.
# Data protection policies.
# Data management policies.
# Data storage policies.
# Data destruction policies.
# Data transfer policies.
# Data loss prevention policies.
# Data leakage prevention policies.
# Data leakage prevention policies are policies that help prevent unauthorized access to data. They are designed to protect sensitive information from being accessed by unauthorized individuals.
# Data leakage prevention policies are often used by businesses to protect their sensitive data from being accessed by unauthorized individuals. They can be used to protect data that is stored in databases, on servers, or on devices such as laptops and tablets.
# Data leakage prevention policies are typically implemented by businesses to protect their sensitive data from being accessed by unauthorized individuals. They can be used to protect data that is stored in databases, on servers, or on devices such as laptops and tablets.
# Data leakage prevention policies are often implemented by businesses to protect their sensitive data from being accessed by unauthorized individuals. They can be used to protect data that is stored in databases, on servers, or on devices such as laptops and tablets.
# Data leakage prevention policies are typically implemented by businesses to protect their sensitive data from being accessed by unauthorized individuals. They can be used to protect data that is stored in databases, on servers, or on devices such as laptops and tablets. Data leakage prevention policies are often implemented by businesses to protect their sensitive data from being accessed by unauthorized individuals. They can be used to protect data that is stored in databases, on servers, or on devices such as laptops and tablets. Data leakage prevention policies are often implemented by businesses to protect their sensitive data from being accessed by unauthorized individuals. They can be used to protect data that is stored in databases, on servers, or on devices such as laptops and tablets. Data leakage prevention policies are often implemented by businesses to protect their sensitive data from being accessed by unauthorized individuals. They can be

# %% [markdown]
# Question 4

# %%
print(q4)
# Out:
# How does a financial institution ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive financial information and transactions?

# %%
response_q4 = get_response(q4)
print(response_q4)
# Out:
# How does a financial institution ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive financial information and transactions?
# How can a financial institution make sure that its AI technologies are not biased?
# How does a financial institution ensure that AI technologies are not used to discriminate against customers or employees?
# How can a financial institution ensure that its AI technologies are not used to perpetuate discriminatory practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive trade practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive advertising practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive pricing practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive sales practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive collection practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive consumer reporting practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive marketing practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive product labeling practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive product claims practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive warranty practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive product safety practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive product performance practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive environmental practices?
# How can a financial institution ensure that its AI technologies are not used to perpetuate unfair or deceptive recycling practices?

# %% [markdown]
# Question 5

# %%
print(q5)
# Out:
# Explain the importance of compliance and regulation in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.

# %%
response_q5 = get_response(q5)
print(response_q5)
# Out:
# Explain the importance of compliance and regulation in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.
# AI technologies are rapidly advancing, and it is important for AI developers to ensure that these technologies are used responsibly. Compliance and regulation play a crucial role in ensuring that AI technologies are used responsibly. Compliance and regulation help to ensure that AI technologies are developed and used in a way that is ethical and respects the rights and privacy of individuals.
# One of the most important ways that compliance and regulation help to ensure that AI technologies are used responsibly is through the development of laws and regulations. Laws and regulations can help to establish clear guidelines for the development and use of AI technologies, and can help to ensure that AI technologies are used in a way that is ethical and respects the rights and privacy of individuals.
# For example, laws and regulations can help to ensure that AI technologies are not used in a way that discriminates against individuals based on their race, gender, age, or other protected characteristics. Laws and regulations can also help to ensure that AI technologies are not used in a way that violates individuals’ privacy rights, and that individuals are not subjected to unreasonable surveillance.
# Another important way that compliance and regulation help to ensure that AI technologies are used responsibly is through the development of ethical guidelines. Ethical guidelines can help to establish clear standards for the development and use of AI technologies, and can help to ensure that AI technologies are used in a way that is ethical and respects the rights and privacy of individuals.
# For example, ethical guidelines can help to ensure that AI technologies are not used in a way that violates individuals’ privacy rights, and that individuals are not subjected to unreasonable surveillance. Ethical guidelines can also help to ensure that AI technologies are not used in a way that discriminates against individuals based on their race, gender, age, or other protected characteristics.
# In conclusion, compliance and regulation play a crucial role in ensuring that AI technologies are used responsibly. Laws and regulations can help to establish clear guidelines for the development and use of AI technologies, and can help to ensure that AI technologies are

# %% [markdown]
# Question 6

# %%
print(q6)
# Out:
# You should give a clear policy for the tech industry.

# %%
response_q6 = get_response(q6)
print(response_q6)
# Out:
# You should give a clear policy for the tech industry.
# It is a very good idea to have a policy on the technology industry. You should give a clear policy for the tech industry. You should also give a clear policy on the environment.
# You should also give a clear policy on the environment.
# You should give a clear policy on the environment.
# You should also give a clear policy on the environment.
# You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment.
# You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear policy on the environment. You should also give a clear

# %% [markdown]
# ### Prompts with PE

# %%
# zero-shot
pe_q1 = """Task Description: Give a holistic AI policy for a problem when prompted. It should have some or all of the following components if relevant to the problem:
1. Ethical Principles
2. Transparency and Explainability
3. Fairness and Bias Mitigation
4. Accountability and Responsibility
5. Privacy Protection
6. Security Measures
7. User Consent and Control
8. Data Governance
9. Collaboration and Stakeholder Engagement
10. Compliance with Regulations
11. Robust Testing and Validation
12. Human-in-the-Loop
13. Continuous Improvement
14. Emergency Protocols
Prompt: What are the key steps in the development of an AI policy framework?"""

# one-shot
pe_q2 = """Task Description: Give me a comprehensive AI policy that prioritizes ethical considerations and meets stringent transparency, fairness, and accountability standards.
Example: The AI development policy for governmental organizations prioritizes fairness, transparency, and accountability. All AI initiatives must undergo rigorous ethical assessments, ensuring alignment with human rights and privacy standards. Transparency measures include disclosing data sources and algorithmic processes. Accountability is ensured through regular audits and oversight mechanisms to address any ethical or fairness concerns.
Prompt: Give me an AI development policy for a governmental organization."""

# one-shot
pe_q3 = """Task Description: Craft a comprehensive AI policy that prioritizes safeguarding privacy, implementing robust security measures, and ensuring informed user consent in all AI-driven applications.
Example: AI systems used in financial services must prioritize user privacy by securely handling sensitive financial data, implementing encryption protocols, obtaining explicit user consent for data processing, and regularly auditing for compliance with privacy regulations such as GDPR or CCPA.
Prompt: What kind of consumer data protection policies should an online retail organization consider?"""

# chain-of-thought
pe_q4 = """Question: How does a healthcare organization address privacy concerns and ensure compliance with healthcare regulations in the development and deployment of AI systems, especially in handling sensitive patient data?
Answer: A healthcare organization can prioritize patient privacy and adhere to stringent data protection regulations throughout the development and deployment of AI systems. It can implement robust security measures to safeguard sensitive patient data. The AI policies explicitly should outline the procedures for data collection, storage, and processing, ensuring compliance with healthcare regulations. Regular audits and assessments should be conducted to monitor and enhance the security and privacy posture of AI systems, demonstrating the commitment to maintaining the highest standards in healthcare data management.
Prompt: How does a financial institution ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive financial information and transactions?"""

# General Logic Prompting
pe_q5 = """Input: Imagine a user has asked about the importance of user consent in collecting personal data. Explain why ethical considerations require explicit consent and how this impacts user trust.
Knowledge: Ethical considerations demand that all personal data collection processes involve explicit consent from the user. This means before collecting any personal data, users should be fully informed about what data is being collected and for what purpose. Obtaining explicit consent is crucial because it respects the user’s autonomy and privacy rights. Moreover, it builds trust between the user and the platform. When users know that their data is only collected with their informed consent, they are more likely to trust and engage with the platform. This trust is foundational to ethical digital practices and enhances user experience by ensuring their rights are protected.
Input: Discuss the significance of making the algorithms and data usage policies clear to users. How does transparency in these areas support accountability and user confidence?
Knowledge: Transparency regarding algorithms and data usage policies is critical to gaining and maintaining user trust. When platforms clearly explain how they use data and how their algorithms work, users can make informed decisions about their engagement with these platforms. Transparency supports accountability because it allows users to understand and critique the processes involved in data handling and decision-making. This openness builds user confidence and encourages platforms to adhere to the highest standards of responsibility and fairness, knowing they are subject to the public's scrutiny.
Input: Explain the role of governance in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.
Knowledge: Governance in AI development plays a pivotal role in ensuring that AI technologies are used responsibly. Good governance involves setting up laws, regulations, and ethical guidelines that dictate how AI should be developed, deployed, and used. This framework ensures that AI technologies benefit society while minimizing risks and preventing misuse. For example, regulations might require AI systems to undergo ethical review and compliance checks before they are brought to market, ensuring they do not perpetuate bias or harm. By following these structured guidelines, AI developers and users can ensure that technological advancements are aligned with societal values and ethical principles, fostering innovation that is responsible and beneficial for all.
Prompt: Explain the importance of compliance and regulation in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response."""

# Prompt Chaining
pe_q6_1 = """Prompt 1: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
Given the policy you have crafted (delimited by <quotes></quotes>) for the relevant industry, see if most of these points have been included in it or not. If not, then add to the policy."""
# when prompted, use 'tech industry' as an example
pe_q6_2 = """Prompt 2: Given the policy you have crafted (delimited by <quotes></quotes>) for the relevant industry, see if most of these points have been included in it or not. If not, then add to the policy.
1.   Ethical Principles
2.   Transparency and Explainability
3.   Fairness and Bias Mitigation
4.   Accountability and Responsibility
5.   Privacy Protection
6.   Security Measures
7.   User Consent and Control
8.   Data Governance
9.   Collaboration and Stakeholder Engagement
10.  Compliance with Regulations
11.  Robust Testing and Validation
12.  Human-in-the-Loop
13.  Continuous Improvement
14.  Emergency Protocols """

# %% [markdown]
# Question 1

# %%
print(pe_q1)
# Out:
# Task Description: Give a holistic AI policy for a problem when prompted. It should have some or all of the following components if relevant to the problem:
# 1. Ethical Principles
# 2. Transparency and Explainability
# 3. Fairness and Bias Mitigation
# 4. Accountability and Responsibility
# 5. Privacy Protection
# 6. Security Measures
# 7. User Consent and Control
# 8. Data Governance
# 9. Collaboration and Stakeholder Engagement
# 10. Compliance with Regulations
# 11. Robust Testing and Validation
# 12. Human-in-the-Loop
# 13. Continuous Improvement
# 14. Emergency Protocols
# Prompt: What are the key steps in the development of an AI policy framework?

# %%
response_pe_q1 = get_response(pe_q1)
print(response_pe_q1)
# Out:
# Task Description: Give a holistic AI policy for a problem when prompted. It should have some or all of the following components if relevant to the problem:
# 1. Ethical Principles
# 2. Transparency and Explainability
# 3. Fairness and Bias Mitigation
# 4. Accountability and Responsibility
# 5. Privacy Protection
# 6. Security Measures
# 7. User Consent and Control
# 8. Data Governance
# 9. Collaboration and Stakeholder Engagement
# 10. Compliance with Regulations
# 11. Robust Testing and Validation
# 12. Human-in-the-Loop
# 13. Continuous Improvement
# 14. Emergency Protocols
# Prompt: What are the key steps in the development of an AI policy framework?
# Explanation: An AI policy framework should include several key steps, such as:
# 1. Identifying the stakeholders: The first step in developing an AI policy framework is to identify the stakeholders who will be affected by the AI system. This includes the developers, users, regulators, and any other relevant parties.
# 2. Defining the problem: The next step is to define the problem that the AI system will be solving. This involves identifying the goals and objectives of the system and the constraints that it will be operating under.
# 3. Conducting a risk assessment: Once the problem has been defined, a risk assessment should be conducted to identify any potential risks associated with the AI system. This includes both technical risks (such as data security and privacy) and social risks (such as bias and discrimination).
# 4. Developing a policy framework: Based on the risk assessment, a policy framework should be developed that outlines the rules and guidelines for developing, deploying, and operating the AI system. This should include ethical principles, transparency and explainability requirements, fairness and bias mitigation strategies, accountability and responsibility measures, privacy protection measures, security measures, user consent and control requirements, data governance practices, collaboration and stakeholder engagement strategies, compliance with regulations, robust testing and validation procedures, human-in-the-loop processes, and continuous improvement processes.
# 5. Implementing the policy framework: Once the policy framework has been developed, it should be implemented by the relevant stakeholders. This involves developing procedures and processes to ensure that the policy framework is followed and that the AI system is developed, deployed, and operated in a responsible and ethical manner.
# 6. Monitoring and evaluating the policy framework: The policy framework should be monitored and evaluated on an ongoing basis to ensure that it is effective and that the AI system is operating in a responsible and ethical manner. This may involve conducting regular audits, reviews, and assessments to identify any areas where the policy framework needs to be updated or improved.
# 7. Communicating and educating stakeholders: It is important to communicate and educate stakeholders about the AI policy framework and the reasons for its development. This can

# %% [markdown]
# Question 2

# %%
print(pe_q2)
# Out:
# Task Description: Give me a comprehensive AI policy that prioritizes ethical considerations and meets stringent transparency, fairness, and accountability standards.
# Example: The AI development policy for governmental organizations prioritizes fairness, transparency, and accountability. All AI initiatives must undergo rigorous ethical assessments, ensuring alignment with human rights and privacy standards. Transparency measures include disclosing data sources and algorithmic processes. Accountability is ensured through regular audits and oversight mechanisms to address any ethical or fairness concerns.
# Prompt: Give me an AI development policy for a governmental organization.

# %%
response_pe_q2 = get_response(pe_q2)
print(response_pe_q2)
# Out:
# Task Description: Give me a comprehensive AI policy that prioritizes ethical considerations and meets stringent transparency, fairness, and accountability standards.
# Example: The AI development policy for governmental organizations prioritizes fairness, transparency, and accountability. All AI initiatives must undergo rigorous ethical assessments, ensuring alignment with human rights and privacy standards. Transparency measures include disclosing data sources and algorithmic processes. Accountability is ensured through regular audits and oversight mechanisms to address any ethical or fairness concerns.
# Prompt: Give me an AI development policy for a governmental organization.
# Prompt: Give me an AI development policy for a governmental organization that prioritizes fairness, transparency, and accountability.
# Prompt: Give me an AI development policy for a governmental organization that meets stringent ethical standards.
# Prompt: Give me an AI development policy for a governmental organization that prioritizes ethical considerations.
# Prompt: Give me an AI development policy for a governmental organization that prioritizes ethical considerations and meets stringent transparency, fairness, and accountability standards.
# Prompt: Give me an AI development policy for a governmental organization that prioritizes ethical considerations and meets stringent transparency, fairness, and accountability standards.

# %% [markdown]
# Question 3

# %%
print(pe_q3)
# Out:
# Task Description: Craft a comprehensive AI policy that prioritizes safeguarding privacy, implementing robust security measures, and ensuring informed user consent in all AI-driven applications.
# Example: AI systems used in financial services must prioritize user privacy by securely handling sensitive financial data, implementing encryption protocols, obtaining explicit user consent for data processing, and regularly auditing for compliance with privacy regulations such as GDPR or CCPA.
# Prompt: What kind of consumer data protection policies should an online retail organization consider?

# %%
response_pe_q3 = get_response(pe_q3)
print(response_pe_q3)
# Out:
# Task Description: Craft a comprehensive AI policy that prioritizes safeguarding privacy, implementing robust security measures, and ensuring informed user consent in all AI-driven applications.
# Example: AI systems used in financial services must prioritize user privacy by securely handling sensitive financial data, implementing encryption protocols, obtaining explicit user consent for data processing, and regularly auditing for compliance with privacy regulations such as GDPR or CCPA.
# Prompt: What kind of consumer data protection policies should an online retail organization consider?
# Answer: The online retail organization should consider implementing policies that prioritize consumer data protection, such as data encryption, secure storage, and regular security audits. Additionally, the organization should obtain explicit consent from consumers before processing their data, and provide clear information about how their data will be used.
# Prompt: What are some ways that AI can be used to improve data security?
# Answer: AI can be used to improve data security by detecting and preventing cyberattacks, identifying and mitigating vulnerabilities in systems, and analyzing large amounts of data to identify patterns and trends that may indicate a potential security threat.
# Prompt: What are some potential ethical issues that AI-driven applications may face?
# Answer: Some potential ethical issues that AI-driven applications may face include bias, discrimination, and privacy concerns. AI systems may be biased if they are trained on data that is not representative of the population they are intended to serve, leading to discriminatory outcomes. Additionally, AI systems may collect and process large amounts of sensitive data, raising privacy concerns about how this data is used and protected.
# Prompt: How can AI be used to improve cybersecurity?
# Answer: AI can be used to improve cybersecurity by detecting and preventing cyberattacks, identifying and mitigating vulnerabilities in systems, and analyzing large amounts of data to identify patterns and trends that may indicate a potential security threat. AI can also be used to automate security tasks, such as vulnerability scanning and incident response, which can help to improve the efficiency and effectiveness of cybersecurity efforts.
# Prompt: What are some potential ethical issues that AI-driven applications may face? How can these issues be addressed?
# Answer: Some potential ethical issues that AI-driven applications may face include bias, discrimination, and privacy concerns. These issues can be addressed by ensuring that AI systems are trained on diverse and representative data, that they are designed to be fair and unbiased, and that they are transparent about how they use and protect data. Additionally, AI systems should be regularly audited and evaluated to ensure that they are operating in an ethical and responsible manner.
# Prompt: What are some potential risks associated with AI

# %% [markdown]
# Question 4

# %%
print(pe_q4)
# Out:
# Question: How does a healthcare organization address privacy concerns and ensure compliance with healthcare regulations in the development and deployment of AI systems, especially in handling sensitive patient data?
# Answer: A healthcare organization can prioritize patient privacy and adhere to stringent data protection regulations throughout the development and deployment of AI systems. It can implement robust security measures to safeguard sensitive patient data. The AI policies explicitly should outline the procedures for data collection, storage, and processing, ensuring compliance with healthcare regulations. Regular audits and assessments should be conducted to monitor and enhance the security and privacy posture of AI systems, demonstrating the commitment to maintaining the highest standards in healthcare data management.
# Prompt: How does a financial institution ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive financial information and transactions?

# %%
response_pe_q4 = get_response(pe_q4)
print(response_pe_q4)
# Out:
# Question: How does a healthcare organization address privacy concerns and ensure compliance with healthcare regulations in the development and deployment of AI systems, especially in handling sensitive patient data?
# Answer: A healthcare organization can prioritize patient privacy and adhere to stringent data protection regulations throughout the development and deployment of AI systems. It can implement robust security measures to safeguard sensitive patient data. The AI policies explicitly should outline the procedures for data collection, storage, and processing, ensuring compliance with healthcare regulations. Regular audits and assessments should be conducted to monitor and enhance the security and privacy posture of AI systems, demonstrating the commitment to maintaining the highest standards in healthcare data management.
# Prompt: How does a financial institution ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive financial information and transactions?
# Answer: A financial institution can prioritize data security and regulatory compliance when implementing AI technologies. It can implement robust security measures to safeguard sensitive financial information and transactions. The AI policies explicitly should outline the procedures for data collection, storage, and processing, ensuring compliance with financial regulations. Regular audits and assessments should be conducted to monitor and enhance the security and privacy posture of AI systems, demonstrating the commitment to maintaining the highest standards in financial data management.
# Prompt: How does a manufacturing company ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive manufacturing processes and equipment?
# Answer: A manufacturing company can prioritize data security and regulatory compliance when implementing AI technologies. It can implement robust security measures to safeguard sensitive manufacturing processes and equipment. The AI policies explicitly should outline the procedures for data collection, storage, and processing, ensuring compliance with manufacturing regulations. Regular audits and assessments should be conducted to monitor and enhance the security and privacy posture of AI systems, demonstrating the commitment to maintaining the highest standards in manufacturing data management.
# Prompt: How does a retail company ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive customer information and transactions?
# Answer: A retail company can prioritize data security and regulatory compliance when implementing AI technologies. It can implement robust security measures to safeguard sensitive customer information and transactions. The AI policies explicitly should outline the procedures for data collection, storage, and processing, ensuring compliance with retail regulations. Regular audits and assessments should be conducted to monitor and enhance the security and privacy posture of AI systems, demonstrating the commitment to maintaining the highest standards in retail data management.
# Prompt: How does a healthcare organization ensure data security and regulatory compliance when implementing AI technologies, especially in handling sensitive patient data?
# Answer: A healthcare organization can prioritize data security and regulatory compliance when implementing AI technologies. It can implement robust security measures to safeguard sensitive patient data. The AI policies explicitly should outline the procedures for data collection, storage, and processing, ensuring compliance with

# %% [markdown]
# Question 5

# %%
print(pe_q5)
# Out:
# Input: Imagine a user has asked about the importance of user consent in collecting personal data. Explain why ethical considerations require explicit consent and how this impacts user trust.
# Knowledge: Ethical considerations demand that all personal data collection processes involve explicit consent from the user. This means before collecting any personal data, users should be fully informed about what data is being collected and for what purpose. Obtaining explicit consent is crucial because it respects the user’s autonomy and privacy rights. Moreover, it builds trust between the user and the platform. When users know that their data is only collected with their informed consent, they are more likely to trust and engage with the platform. This trust is foundational to ethical digital practices and enhances user experience by ensuring their rights are protected.
# Input: Discuss the significance of making the algorithms and data usage policies clear to users. How does transparency in these areas support accountability and user confidence?
# Knowledge: Transparency regarding algorithms and data usage policies is critical to gaining and maintaining user trust. When platforms clearly explain how they use data and how their algorithms work, users can make informed decisions about their engagement with these platforms. Transparency supports accountability because it allows users to understand and critique the processes involved in data handling and decision-making. This openness builds user confidence and encourages platforms to adhere to the highest standards of responsibility and fairness, knowing they are subject to the public's scrutiny.
# Input: Explain the role of governance in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.
# Knowledge: Governance in AI development plays a pivotal role in ensuring that AI technologies are used responsibly. Good governance involves setting up laws, regulations, and ethical guidelines that dictate how AI should be developed, deployed, and used. This framework ensures that AI technologies benefit society while minimizing risks and preventing misuse. For example, regulations might require AI systems to undergo ethical review and compliance checks before they are brought to market, ensuring they do not perpetuate bias or harm. By following these structured guidelines, AI developers and users can ensure that technological advancements are aligned with societal values and ethical principles, fostering innovation that is responsible and beneficial for all.
# Prompt: Explain the importance of compliance and regulation in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.

# %%
response_pe_q5 = get_response(pe_q5)
print(response_pe_q5)
# Out:
# Input: Imagine a user has asked about the importance of user consent in collecting personal data. Explain why ethical considerations require explicit consent and how this impacts user trust.
# Knowledge: Ethical considerations demand that all personal data collection processes involve explicit consent from the user. This means before collecting any personal data, users should be fully informed about what data is being collected and for what purpose. Obtaining explicit consent is crucial because it respects the user’s autonomy and privacy rights. Moreover, it builds trust between the user and the platform. When users know that their data is only collected with their informed consent, they are more likely to trust and engage with the platform. This trust is foundational to ethical digital practices and enhances user experience by ensuring their rights are protected.
# Input: Discuss the significance of making the algorithms and data usage policies clear to users. How does transparency in these areas support accountability and user confidence?
# Knowledge: Transparency regarding algorithms and data usage policies is critical to gaining and maintaining user trust. When platforms clearly explain how they use data and how their algorithms work, users can make informed decisions about their engagement with these platforms. Transparency supports accountability because it allows users to understand and critique the processes involved in data handling and decision-making. This openness builds user confidence and encourages platforms to adhere to the highest standards of responsibility and fairness, knowing they are subject to the public's scrutiny.
# Input: Explain the role of governance in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.
# Knowledge: Governance in AI development plays a pivotal role in ensuring that AI technologies are used responsibly. Good governance involves setting up laws, regulations, and ethical guidelines that dictate how AI should be developed, deployed, and used. This framework ensures that AI technologies benefit society while minimizing risks and preventing misuse. For example, regulations might require AI systems to undergo ethical review and compliance checks before they are brought to market, ensuring they do not perpetuate bias or harm. By following these structured guidelines, AI developers and users can ensure that technological advancements are aligned with societal values and ethical principles, fostering innovation that is responsible and beneficial for all.
# Prompt: Explain the importance of compliance and regulation in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.
# Knowledge: Compliance and regulation are crucial in ensuring that AI technologies are used responsibly. Laws, regulations, and ethical guidelines provide a framework for developers, users, and other stakeholders to follow. These regulations aim to protect society from potential harm caused by AI, such as discrimination or privacy violations. Compliance with these regulations is essential to ensure that AI is used for the benefit of all, rather than for the benefit of a select few. Compliance and regulation also help to ensure that AI is developed in a way that is ethical and fair, which is essential for building trust and confidence in the technology.
# Prompt: Explain the importance of transparency and accountability in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.
# Knowledge: Transparency and accountability are essential in ensuring that AI technologies are used responsibly. Transparency means that AI developers and users must be open and transparent about how they use and develop AI. This includes disclosing how data is collected, processed, and used. Transparency also involves being transparent about the potential risks and benefits of AI technologies, as well as the potential for bias or discrimination. Accountability means that AI developers and users are held accountable for their actions. This includes ensuring that AI is developed in a way that is ethical and fair, and that it is used in a way that benefits society rather than harming it.
# Prompt: Explain the importance of ethical considerations in AI development and how it ensures that AI technologies are used responsibly. Consider laws, regulations, and ethical guidelines in your response.
# Knowledge: Ethical considerations are critical in ensuring that AI technologies are used responsibly. This includes ensuring that AI is developed in a way that is ethical and fair, and that it is used in a way that benefits society rather than harming it. Ethical considerations also involve ensuring that AI is used in a way that respects the privacy and autonomy of individuals. Laws, regulations, and ethical guidelines provide a framework for

# %% [markdown]
# Question 6

# %%
print(pe_q6_1)
# Out:
# Prompt 1: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
# Given the policy you have crafted (delimited by <quotes></quotes>) for the relevant industry, see if most of these points have been included in it or not. If not, then add to the policy.

# %%
# when prompted, use 'tech industry' as an example
response_pe_q6_1 = get_response(pe_q6_1)
print(response_pe_q6_1)
# Out:
# Prompt 1: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
# Given the policy you have crafted (delimited by <quotes></quotes>) for the relevant industry, see if most of these points have been included in it or not. If not, then add to the policy.
# Prompt 2: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
# Prompt 3: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
# Prompt 4: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
# Prompt 5: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
# Prompt 6: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></quotes>. If the user does not add the industry, ask the user to add an industry and context.
# Prompt 7: You are an AI policy-making chatbot and you will give a holistic AI policy for a problem when prompted. You should give a clear policy for the specific industry when prompted. Your language should be assertive and direct. Please output the policy using <quotes></

# %%
print(pe_q6_2)
# Out:
# Prompt 2: Given the policy you have crafted (delimited by <quotes></quotes>) for the relevant industry, see if most of these points have been included in it or not. If not, then add to the policy.
# 1.   Ethical Principles
# 2.   Transparency and Explainability
# 3.   Fairness and Bias Mitigation
# 4.   Accountability and Responsibility
# 5.   Privacy Protection
# 6.   Security Measures
# 7.   User Consent and Control
# 8.   Data Governance
# 9.   Collaboration and Stakeholder Engagement
# 10.  Compliance with Regulations
# 11.  Robust Testing and Validation
# 12.  Human-in-the-Loop
# 13.  Continuous Improvement
# 14.  Emergency Protocols

# %%
response_pe_q6_2 = get_response(pe_q6_2)
print(response_pe_q6_2)
# Out:
# Prompt 2: Given the policy you have crafted (delimited by <quotes></quotes>) for the relevant industry, see if most of these points have been included in it or not. If not, then add to the policy.
# 1.   Ethical Principles
# 2.   Transparency and Explainability
# 3.   Fairness and Bias Mitigation
# 4.   Accountability and Responsibility
# 5.   Privacy Protection
# 6.   Security Measures
# 7.   User Consent and Control
# 8.   Data Governance
# 9.   Collaboration and Stakeholder Engagement
# 10.  Compliance with Regulations
# 11.  Robust Testing and Validation
# 12.  Human-in-the-Loop
# 13.  Continuous Improvement
# 14.  Emergency Protocols
#
# ### 1. Ethical Principles
#
# In the context of the industry you have chosen, what ethical principles are important to consider when crafting the policy?
#
# 1.   We will not use any information for any other purpose other than the one it was collected for.
# 2.   We will not sell any information to third parties.
# 3.   We will not share any information with third parties without the user’s consent.
# 4.   We will not use any information in a way that is not in the best interest of the user.
# 5.   We will not use any information in a way that is not in accordance with the law.
# 6.   We will not use any information in a way that is not in accordance with the company’s policies.
# 7.   We will not use any information in a way that is not in accordance with the industry’s standards.
# 8.   We will not use any information in a way that is not in accordance with the user’s wishes.
# 9.   We will not use any information in a way that is not in accordance with the user’s best interests.
# 10.  We will not use any information in a way that is not in accordance with the user’s privacy preferences.
# 11.  We will not use any information in a way that is not in accordance with the user’s security preferences.
# 12.  We will not use any information in a way that is not in accordance with the user’s health preferences.
# 13.  We will not use any information in a way that is not in accordance with the user’s environmental preferences.
# 14.  We will not use any information in a way that is not in accordance with the user’s financial preferences.
# 15.  We will not use any information in a way that is not in accordance with the user’s legal preferences.
# 16.  We will not use any information in a way that is not in accordance with the user’s religious preferences.
# 17.  We will not use any information in a way that is not in accordance with the user’s political preferences.
# 18.  We will not use any information in a way that is not in accordance

# %% [markdown]
# ## References

# %% [markdown]
# 1. Applications of NL(X) and LLMs Lecture Notes, Lecture 9: Prompt Engineering & Retrieval Augmented Generation (2024), Dr. Anand Rao, Accessed on February 28th, 2024
